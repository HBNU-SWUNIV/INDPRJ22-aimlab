# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import trange, tqdm

# %%
image_path = 'C:/Users/user/PycharmProjects/Fake_fingerprint_detection/dataset_FL/unknown2_FL/Live' #unknown2 - live
img_list = os.listdir(image_path)

avg = []

for i in img_list :
    img = cv2.imread('C:/Users/user/PycharmProjects/Fake_fingerprint_detection/dataset_FL/unknown2_FL/Live/' + i, cv2.IMREAD_GRAYSCALE)
    img = np.array(img.reshape(500*500))
    avg.append(img)

avg = np.array(avg)

pixel_mean = avg.mean(axis = 0)

plt.plot(range(250000), pixel_mean)
plt.show()

# %%
arr = []
count = 0
for i in img_list:
    img = cv2.imread('C:/Users/user/PycharmProjects/Fake_fingerprint_detection/dataset_FL/unknown2_FL/Live/' + i, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(500*500)
    arr.append(img)
    
    count += 1

data_arr = []
value = []
for i in tqdm(arr):
    data_value = np.unique(i, return_counts=True)
    dv_0 = data_value[0].tolist()
    dv_1 = data_value[1].tolist()
    value.append(dv_1)
    di = {str(j): 0 for j in dv_0}

    for k in range(len(dv_1)):
        di[str(k)] = dv_1[k]
    data_arr.append(di)

df = pd.DataFrame(data_arr)
# Out:
# 100%|██████████| 1250/1250 [00:04<00:00, 303.52it/s]

# %%
unknown2_Live_mean = df.mean()
plt.plot(unknown2_Live_mean)

# %%
unknown2_Live_mean = np.log1p(df.mean())
plt.plot(unknown2_Live_mean)

# %%
unknown2_Live_mean = np.log1p(df.mean())
plt.hist(unknown2_Live_mean)
# Out:
# (array([ 12.,   7.,   8., 187.,  16.,   6.,   5.,   5.,   8.,   2.]),
#  array([ 2.74609073,  3.52268343,  4.29927613,  5.07586882,  5.85246152,
#          6.62905422,  7.40564692,  8.18223962,  8.95883231,  9.73542501,
#         10.51201771]),
#  <BarContainer object of 10 artists>)
