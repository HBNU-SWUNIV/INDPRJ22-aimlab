# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import trange, tqdm

# %%
image_path = 'C:/Users/user/PycharmProjects/Fake_fingerprint_detection/dataset_FL/unknown1_FL/Live' #unknown1 - live
img_list = os.listdir(image_path)

avg = []

for i in img_list :
    img = cv2.imread('C:/Users/user/PycharmProjects/Fake_fingerprint_detection/dataset_FL/unknown1_FL/Live/' + i, cv2.IMREAD_GRAYSCALE)
    img = np.array(img.reshape(500*500))
    avg.append(img)

avg = np.array(avg)

pixel_mean = avg.mean(axis = 0)

plt.plot(range(250000), pixel_mean)
plt.show()

# %%
image_path = 'C:/Users/user/PycharmProjects/Fake_fingerprint_detection/dataset_FL/unknown1_FL/Live' 
img_list = os.listdir(image_path)

arr = []
count = 0
for i in img_list:
    img = cv2.imread('C:/Users/user/PycharmProjects/Fake_fingerprint_detection/dataset_FL/unknown1_FL/Live/' + i, cv2.IMREAD_GRAYSCALE)
    img = img.reshape(500*500)
    arr.append(img)
    
    count += 1

data_arr = []
value = []
for i in tqdm(arr):
    data_value = np.unique(i, return_counts=True)
    dv_0 = data_value[0].tolist()
    dv_1 = data_value[1].tolist()
    value.append(dv_1)
    di = {str(j): 0 for j in dv_0}

    for k in range(len(dv_1)):
        di[str(k)] = dv_1[k]
    data_arr.append(di)

df = pd.DataFrame(data_arr)
# Out:
# 100%|██████████| 1249/1249 [00:04<00:00, 300.41it/s]

# %%
unknown1_live_mean = df.mean()
plt.plot(unknown1_live_mean)

# %%
unknown1_live_mean = np.log1p(df.mean())
plt.plot(unknown1_live_mean)

# %%
unknown1_live_mean = np.log1p(df.mean())
plt.hist(unknown1_live_mean)
# Out:
# (array([233.,  10.,   5.,   4.,   3.,   0.,   0.,   0.,   0.,   1.]),
#  array([ 5.02211439,  5.73032821,  6.43854204,  7.14675586,  7.85496968,
#          8.5631835 ,  9.27139732,  9.97961114, 10.68782496, 11.39603879,
#         12.10425261]),
#  <BarContainer object of 10 artists>)
